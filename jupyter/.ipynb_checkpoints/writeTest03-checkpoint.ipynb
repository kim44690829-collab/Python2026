# %%
import pandas as pd

# 공공 데이터 포털에서 다운로드 받은 bike02.csv 파일을 읽어오는 방법
df = pd.read_csv('/greenData/bike02.csv', 'r', encoding='cp949')
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 import pandas as pd
#       3 # 공공 데이터 포털에서 다운로드 받은 bike02.csv 파일을 읽어오는 방법
# ----> 4 df = pd.read_csv('/greenData/bike02.csv', 'r', encoding='cp949')
#       5 df.head(10)
#
# TypeError: read_csv() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given
